# %% [markdown]
# In this model, X1 and X2 are two variables measuring the construct “food quality”; X3, X4 and X5 are indicators for “service quality”; and Y1 and Y2 are indicators for “customer’s satisfaction”. There are two samples in this study. The first sample consists of 260 customers randomly selected at different local Chinese restaurants, and the second sample consists of 240 customers randomly selected at different Western restaurants.

# %% [markdown]
# <img src="SEM_02/ModelStructure.png" width='65%'>

# %% [markdown]
# Input:

# %%
TI Customer Satisfaction Model (Chinese)
DA NG=2 NI=7 NO=260
SE 
6 7 1 2 3 4 5
LA
X1 X2 X3 X4 X5 Y1 Y2
CM FI='Chinese.cov'
MO NX=5 NY=2 NK=2 NE=1 LX=FU,FI LY=FU,FI TD=SY,FI TE=DI,FR GA=FU,FR BE=FU,FI PH=SY,FR PS=DI,FI
LK 
Food Service
LE
SAT
FR LX(2,1) LX(4,2) LX(5,2) LY(2,1) TD(4,3) TD(1,1) TD(2,2) TD(3,3) TD(4,4) TD(5,5)
VA 1 LX(1,1) LX(3,2) LY(1,1)
PD
OU ME=ML ND=3


TI Customer Satisfaction Model (Western)
DA NI=7 NO=240
SE 
6 7 1 2 3 4 5
LA
X1 X2 X3 X4 X5 Y1 Y2
CM FI='Western.cov'
MO NX=5 NY=2 NK=2 NE=1 LX=FU,FI LY=FU,FI TD=SY,FI TE=DI,FR GA=FU,FR BE=FU,FI PH=SY,FR PS=DI,FI AP=1
LK 
Food Service
LE
SAT
FR LX(2,1) LX(4,2) LX(5,2) LY(2,1) TD(4,3) TD(1,1) TD(2,2) TD(3,3) TD(4,4) TD(5,5)
VA 1 LX(1,1) LX(3,2) LY(1,1)
CO PAR(1)=PH(2,1)/(PH(1,1)*PH(2,2))**0.5
EQ LX(1,2,1) LX(2,2,1)
EQ LX(1,4,2) LX(2,4,2)
EQ LX(1,5,2) LX(2,5,2)
EQ LY(1,2,1) LY(2,2,1)
EQ GA(1,1,1) GA(2,1,1)
EQ GA(1,1,2) GA(2,1,2)
EQ PH(1,1,1) PH(2,1,1)
EQ PH(1,2,2) PH(2,2,2)
EQ PH(1,2,1) PH(2,2,1)
OU ME=ML ND=3

# %% [markdown]
# Output:

# %%
 TI Customer Satisfaction Model (Chinese)                             

         Covariance Matrix       

                  Y1         Y2         X1         X2         X3         X4   
            --------   --------   --------   --------   --------   --------
       Y1      0.390
       Y2      0.210      0.390
       X1      0.430      0.260      4.880
       X2      0.450      0.250      2.360      4.440
       X3      0.300      0.330      1.550      1.770      3.380
       X4      0.210      0.220      1.360      1.380      1.990      4.420
       X5      0.230      0.190      0.560      0.560      0.360      0.240

         Covariance Matrix       

                  X5   
            --------
       X5      0.450

 TI Customer Satisfaction Model (Western)                             

         Covariance Matrix       

                  Y1         Y2         X1         X2         X3         X4   
            --------   --------   --------   --------   --------   --------
       Y1      0.620
       Y2      0.440      0.740
       X1      0.530      0.510      4.440
       X2      0.520      0.510      2.620      4.660
       X3      0.260      0.290      0.900      0.970      2.460
       X4      0.340      0.220      0.750      0.740      1.030      2.630
       X5      0.410      0.360      0.720      0.730      0.290      0.240

         Covariance Matrix       

                  X5   
            --------
       X5      0.660


 TI Customer Satisfaction Model (Chinese)                             

 Parameter Specifications

 LAMBDA-Y EQUALS LAMBDA-Y IN THE FOLLOWING GROUP

 LAMBDA-X EQUALS LAMBDA-X IN THE FOLLOWING GROUP

 GAMMA EQUALS GAMMA IN THE FOLLOWING GROUP

 PHI EQUALS PHI IN THE FOLLOWING GROUP

         THETA-EPS   

                  Y1         Y2
            --------   --------
                  10         11

         THETA-DELTA 

                  X1         X2         X3         X4         X5
            --------   --------   --------   --------   --------
       X1         12
       X2          0         13
       X3          0          0         14
       X4          0          0         15         16
       X5          0          0          0          0         17


 TI Customer Satisfaction Model (Western)                             

 Parameter Specifications

         LAMBDA-Y    

                 SAT
            --------
       Y1          0
       Y2          1

         LAMBDA-X    

                Food    Service
            --------   --------
       X1          0          0
       X2          2          0
       X3          0          0
       X4          0          3
       X5          0          4

         GAMMA       

                Food    Service
            --------   --------
      SAT          5          6

         PHI         

                Food    Service
            --------   --------
     Food          7
  Service          8          9

         THETA-EPS   

                  Y1         Y2
            --------   --------
                  18         19

         THETA-DELTA 

                  X1         X2         X3         X4         X5
            --------   --------   --------   --------   --------
       X1         20
       X2          0         21
       X3          0          0         22
       X4          0          0         23         24
       X5          0          0          0          0         25
 


 TI Customer Satisfaction Model (Chinese)                             

 Number of Iterations = 22

 LISREL Estimates (Maximum Likelihood)                           

 LAMBDA-Y EQUALS LAMBDA-Y IN THE FOLLOWING GROUP

 LAMBDA-X EQUALS LAMBDA-X IN THE FOLLOWING GROUP

 GAMMA EQUALS GAMMA IN THE FOLLOWING GROUP

         Covariance Matrix of ETA and KSI        

                 SAT       Food    Service   
            --------   --------   --------
      SAT      0.366
     Food      0.461      2.440
  Service      0.371      0.840      0.451

 PHI EQUALS PHI IN THE FOLLOWING GROUP

         THETA-EPS   

                  Y1         Y2   
            --------   --------
               0.120      0.212
             (0.026)    (0.026)
               4.570      8.217

         Squared Multiple Correlations for Y - Variables         

                  Y1         Y2   
            --------   --------
               0.753      0.553

         THETA-DELTA 

                  X1         X2         X3         X4         X5   
            --------   --------   --------   --------   --------
       X1      2.544
             (0.335)
               7.589
       X2       - -       1.953
                        (0.310)
                          6.300
       X3       - -        - -       2.708
                                   (0.244)
                                    11.102
       X4       - -        - -       1.478      4.031
                                   (0.230)    (0.358)
                                     6.437     11.259
       X5       - -        - -        - -        - -       0.226
                                                         (0.025)
                                                           9.065

         Squared Multiple Correlations for X - Variables         

                  X1         X2         X3         X4         X5   
            --------   --------   --------   --------   --------
               0.490      0.568      0.143      0.068      0.561

         ADDITIONAL PARAMETERS   

               PA(1)   
            --------
               0.800
             (0.041)
              19.597


                         Group Goodness of Fit Statistics

                       Contribution to Chi-Square = 50.114
                  Percentage Contribution to Chi-Square = 65.776
 
                     Root Mean Square Residual (RMR) = 0.300
                             Standardized RMR = 0.111
                       Goodness of Fit Index (GFI) = 0.950


 TI Customer Satisfaction Model (Western)                             

 Number of Iterations = 22

 LISREL Estimates (Maximum Likelihood)                           

         LAMBDA-Y    

                 SAT   
            --------
       Y1      1.000
       Y2      0.847
             (0.063)
              13.352

         LAMBDA-X    

                Food    Service   
            --------   --------
       X1      1.000       - - 
       X2      1.026       - - 
             (0.097)
              10.545
       X3       - -       1.000
       X4       - -       0.806
                        (0.123)
                          6.528
       X5       - -       0.800
                        (0.098)
                          8.189

         GAMMA       

                Food    Service   
            --------   --------
      SAT     -0.262      1.310
             (0.060)    (0.194)
              -4.327      6.756

         Covariance Matrix of ETA and KSI        

                 SAT       Food    Service   
            --------   --------   --------
      SAT      0.366
     Food      0.461      2.440
  Service      0.371      0.840      0.451

         PHI         

                Food    Service   
            --------   --------
     Food      2.440
             (0.330)
               7.392
  Service      0.840      0.451
             (0.128)    (0.105)
               6.576      4.277

         Squared Multiple Correlations for Structural Equations  

                 SAT   
            --------
               1.000

         Squared Multiple Correlations for Reduced Form          

                 SAT   
            --------
               1.000

 W_A_R_N_I_N_G: PSI is not positive definite

         THETA-EPS   

                  Y1         Y2   
            --------   --------
               0.145      0.360
             (0.032)    (0.040)
               4.545      8.947

         Squared Multiple Correlations for Y - Variables         

                  Y1         Y2   
            --------   --------
               0.716      0.421

         THETA-DELTA 

                  X1         X2         X3         X4         X5   
            --------   --------   --------   --------   --------
       X1      1.893
             (0.299)
               6.324
       X2       - -       1.997
                        (0.315)
                          6.333
       X3       - -        - -       2.187
                                   (0.207)
                                    10.550
       X4       - -        - -       0.759      2.370
                                   (0.161)    (0.222)
                                     4.723     10.698
       X5       - -        - -        - -        - -       0.293
                                                         (0.032)
                                                           9.035

         Squared Multiple Correlations for X - Variables         

                  X1         X2         X3         X4         X5   
            --------   --------   --------   --------   --------
               0.563      0.563      0.171      0.110      0.497

         ADDITIONAL PARAMETERS   

               PA(1)   
            --------
               0.800
             (0.041)
              19.597


                        Global Goodness of Fit Statistics

                             Degrees of Freedom = 31
               Minimum Fit Function Chi-Square = 76.188 (P = 0.000)
       Normal Theory Weighted Least Squares Chi-Square = 74.453 (P = 0.000)
                Estimated Non-centrality Parameter (NCP) = 43.453
            90 Percent Confidence Interval for NCP = (21.953 ; 72.653)
 
                        Minimum Fit Function Value = 0.153
               Population Discrepancy Function Value (F0) = 0.0873
             90 Percent Confidence Interval for F0 = (0.0441 ; 0.146)
             Root Mean Square Error of Approximation (RMSEA) = 0.0750
           90 Percent Confidence Interval for RMSEA = (0.0533 ; 0.0970)
              P-Value for Test of Close Fit (RMSEA < 0.05) = 0.0304
 
                  Expected Cross-Validation Index (ECVI) = 0.254
            90 Percent Confidence Interval for ECVI = (0.209 ; 0.311)
                         ECVI for Saturated Model = 0.112
                       ECVI for Independence Model = 2.815
 
     Chi-Square for Independence Model with 42 Degrees of Freedom = 1387.685
                           Independence AIC = 1415.685
                               Model AIC = 126.453
                             Saturated AIC = 112.000
                           Independence CAIC = 1488.689
                               Model CAIC = 262.033
                             Saturated CAIC = 404.018
 
                          Normed Fit Index (NFI) = 0.945
                       Non-Normed Fit Index (NNFI) = 0.955
                    Parsimony Normed Fit Index (PNFI) = 0.698
                       Comparative Fit Index (CFI) = 0.966
                       Incremental Fit Index (IFI) = 0.967
                         Relative Fit Index (RFI) = 0.926
 
                            Critical N (CN) = 342.168
 


                         Group Goodness of Fit Statistics

                       Contribution to Chi-Square = 26.075
                  Percentage Contribution to Chi-Square = 34.224
 
                     Root Mean Square Residual (RMR) = 0.0909
                            Standardized RMR = 0.0980
                       Goodness of Fit Index (GFI) = 0.968
